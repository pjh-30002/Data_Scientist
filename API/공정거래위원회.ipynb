# %%
import urllib.request 
import json 
import pandas as pd 
from pandas.io.json import json_normalize 
import requests
from bs4 import BeautifulSoup
import time

# %%
a ="h t tp s : / / www. con sum e r .g o . k r / op e n api / r ec all /con t e n t s / in d ex .d o ?s e rvic eK ey =서비스키&pageNo=1&cntPerPage=10&cntntsId=메뉴ID"
a = a.replace(" ", "")
a
# Out:
# 'https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey=서비스키&pageNo=1&cntPerPage=10&cntntsId=메뉴ID'

# %% [markdown]
# ### 우선 소문자로 전부 바꾸고 Key 값도 변경해야함

# %% [markdown]
# ### 화장품
# #### 데이터 수 : 302

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []

# %%
for pageNo in range(1,303):

    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0206"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')

    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")

    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")

    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")


    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")


    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")

    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")

    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")

    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")

    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")

    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")

    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")

    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")

    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")

    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")

    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")

    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")

    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")

    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")

    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")

    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")

    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")

    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")

    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")

    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")


    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")

    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")

    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")

    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")

    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")

    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")

    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

# %%
Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

# %%
Product_df_01.to_excel("./공정거래위원회_화장품_리콜정보.xlsx", encoding="cp949")

# %% [markdown]
# ### 먹는물
# #### 데이터 수 : 0

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,100):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0403"
    req = requests.get(url) 
    html = req.text
    soup = BeautifulSoup(html, 'html.parser', encoding='utf-8')

    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_먹는물_리콜정보.xlsx", encoding="cp949")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-f3ab0d711fdf> in <module>
#      43     req = requests.get(url)
#      44     html = req.text
# ---> 45     soup = BeautifulSoup(html, 'html.parser', encoding='utf-8')
#      46
#      47     try:
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     149         if len(kwargs) > 0:
#     150             arg = list(kwargs.keys()).pop()
# --> 151             raise TypeError(
#     152                 "__init__() got an unexpected keyword argument '%s'" % arg)
#     153
#
# TypeError: __init__() got an unexpected keyword argument 'encoding'

# %% [markdown]
# ### 축산물
# #### 데이터 수 : 1

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,100):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0203"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_축산물_리콜정보.xlsx", encoding="cp949")

# %% [markdown]
# ### 해외리콜
# #### 데이터 수 : 17826

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(17826,17926):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0501"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    print(pageNo)
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_해외리콜_리콜정보.xlsx", encoding="cp949")

###
# Out:
# 17826
# 17827
# 17828
# 17829
# 17830
# 17831
# 17832
# 17833
# 17834
# 17835
# 17836
# 17837
# 17838
# 17839
# 17840
# 17841
# 17842
# 17843
# 17844
# 17845
# 17846
# 17847
# 17848
# 17849
# 17850
# 17851
# 17852
# 17853
# 17854
# 17855
# 17856
# 17857
# 17858
# 17859
# 17860
# 17861
# 17862
# 17863
# 17864
# 17865
# 17866
# 17867
# 17868
# 17869
# 17870
# 17871
# 17872
# 17873
# 17874
# 17875
# 17876
# 17877
# 17878
# 17879
# 17880
# 17881
# 17882
# 17883
# 17884
# 17885
# 17886
# 17887
# 17888
# 17889
# 17890
# 17891
# 17892
# 17893
# 17894
# 17895
# 17896
# 17897
# 17898
# 17899
# 17900
# 17901
# 17902
# 17903
# 17904
# 17905
# 17906
# 17907
# 17908
# 17909
# 17910
# 17911
# 17912
# 17913
# 17914
# 17915
# 17916
# 17917
# 17918
# 17919
# 17920
# 17921
# 17922
# 17923
# 17924
# 17925

# %%
Product_df_02 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

# %%
Product_df_02.to_excel("./공정거래위원회_해외리콜_리콜정보6.xlsx", encoding="cp949")

# %% [markdown]
# ### 공산품
# #### 데이터 수 : 2911

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,2912):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0101"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_공산품_리콜정보.xlsx", encoding="cp949")

###

# %% [markdown]
# ### 의료기기
# #### 데이터 수 : 278

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,279):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0207"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_의료기기_리콜정보.xlsx", encoding="cp949")

###

# %% [markdown]
# ### 의약품
# #### 데이터 수 : 989

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,990):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0204"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_의약품_리콜정보.xlsx", encoding="cp949")

###

# %% [markdown]
# ### 식품
# #### 데이터수 : 475

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,476):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0201"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_식품_리콜정보.xlsx", encoding="cp949")

###

# %% [markdown]
# ### 자동차
# #### 데이터 수 : 876

# %%
# 인증Key
servicekey = ""
# 한페이지당 정보 출력 수
product_name = []
product_makr = []
product_bsnmnm = []
product_mnfcturpd = []
product_modlnminfo = []
product_mnfcturnoinfo = []
product_stdbrcd = []
product_distbtmlmtde = []
product_prmisnno = []
product_mdlpclno = []
product_aditfield13 = []
product_etcinfo = []
product_mainsleoffic = []
product_shrtcomcn = []
product_recallse = []
product_recallpublictbgnde = []
product_recallpublictendde = []
product_injrycauseresult = []
product_injryfrgltytrgter = []
product_hrmflgrad = []
product_acdntcn = []
product_cnsmrghvrtips = []
product_trtmntatpn = []
product_recallbgnde = []
product_recallendde = []
product_recallprocssinfo = []
product_recallentrpsinfo = []
product_infoorigininstt = []
product_infooriginurl = []
product_infocreatinstt = []
product_infocreaturl = []




for pageNo in range(1,877):
    
    url = "https://www.consumer.go.kr/openapi/recall/contents/index.do?serviceKey="+\
            servicekey+"&pageNo="+str(pageNo)+"&cntPerPage=1&cntntsId=0301"
    req = requests.get(url) 
    html = req.text 
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        # 제품명
        product_info1 = soup.find_all('productnm')
        product_name.append(product_info1[0].text)
    except:
        product_name.append(" ")
    
    try:
        # 제조사
        product_info2 = soup.find_all('makr')
        product_makr.append(product_info2[0].text)
    except:
        product_makr.append(" ")
    
    try:
        # 사업자명
        product_info3 = soup.find_all('bsnmnm')
        product_bsnmnm.append(product_info3[0].text)
    except:
        product_bsnmnm.append(" ")
        
    
    try:
        # 제조기간
        product_info4 = soup.find_all('mnfcturpd')
        product_mnfcturpd.append(product_info4[0].text)
    except:
        product_mnfcturpd.append(" ")

    
    try:
        # 모델명 정보
        product_info5 = soup.find_all('modlnminfo')
        product_modlnminfo.append(product_info5[0].text)
    except:
        product_modlnminfo.append(" ")
    
    try:
            # 제조번호 정보
        product_info6 = soup.find_all('mnfcturnoinfo')
        product_mnfcturnoinfo.append(product_info6[0].text)
    except:
        product_mnfcturnoinfo.append(" ")
    
    try:
            # 표준 바코드
        product_info7 = soup.find_all('stdbrcd')
        product_stdbrcd.append(product_info7[0].text)
    except:
        product_stdbrcd.append(" ")
    
    try:
            # 유통기한 일자
        product_info8 = soup.find_all('distbtmlmtde')
        product_distbtmlmtde.append(product_info8[0].text)
    except:
        product_distbtmlmtde.append(" ")
    
    try:
            # 허가번호
        product_info9 = soup.find_all('prmisnno')
        product_prmisnno.append(product_info9[0].text)
    except:
        product_prmisnno.append(" ")
    
    try:
            # 의료기기 분류번호
        product_info2 = soup.find_all('mdlpclno')
        product_mdlpclno.append(product_info2[0].text)
    except:
        product_mdlpclno.append(" ")
    
    try:
            # 제품 상세내용
        product_info2 = soup.find_all('aditfield13')
        product_aditfield13.append(product_info2[0].text)
    except:
        product_aditfield13.append(" ")
    
    try:
            # 기타 정보
        product_info2 = soup.find_all('etcinfo')
        product_etcinfo.append(product_info2[0].text)
    except:
        product_etcinfo.append(" ")
    
    try:
            # 주요 판매처
        product_info2 = soup.find_all('mainsleoffic')
        product_mainsleoffic.append(product_info2[0].text)
    except:
        product_mainsleoffic.append(" ")
    
    try:
            # 결함 내용
        product_info2 = soup.find_all('shrtcomcn')
        product_shrtcomcn.append(product_info2[0].text)
    except:
        product_shrtcomcn.append(" ")
    
    try:
            # 리콜 구분
        product_info2 = soup.find_all('recallse')
        product_recallse.append(product_info2[0].text)
    except:
        product_recallse.append(" ")
    
    try:
            # 리콜 공표시작일
        product_info2 = soup.find_all('recallpublictbgnde')
        product_recallpublictbgnde.append(product_info2[0].text)
    except:
        product_recallpublictbgnde.append(" ")
    
    try:
            # 리콜 공표만료일
        product_info2 = soup.find_all('recallpublictendde')
        product_recallpublictendde.append(product_info2[0].text)
    except:
        product_recallpublictendde.append(" ")
    
    try:
            # 위해 원인 결과
        product_info2 = soup.find_all('injrycauseresult')
        product_injrycauseresult.append(product_info2[0].text)
    except:
        product_injrycauseresult.append(" ")
    
    try:
            # 위해 취약 대상자
        product_info2 = soup.find_all('injryfrgltytrgter')
        product_injryfrgltytrgter.append(product_info2[0].text)
    except:
        product_injryfrgltytrgter.append(" ")
    
    try:
            # 위해성 등급
        product_info2 = soup.find_all('hrmflgrad')
        product_hrmflgrad.append(product_info2[0].text)
    except:
        product_hrmflgrad.append(" ")
    
    try:
            # 사고내용
        product_info2 = soup.find_all('acdntcn')
        product_acdntcn.append(product_info2[0].text)
    except:
        product_acdntcn.append(" ")
    
    try:
        # 소비자 행동 요령
        product_info2 = soup.find_all('cnsmrghvrtips')
        product_cnsmrghvrtips.append(product_info2[0].text)
    except:
        product_cnsmrghvrtips.append(" ")
    
    try:
        # 취급 주의사항
        product_info2 = soup.find_all('trtmntatpn')
        product_trtmntatpn.append(product_info2[0].text)
    except:
        product_trtmntatpn.append(" ")
    
    try:
        # 리콜 시작일
        product_info2 = soup.find_all('recallbgnde')
        product_recallbgnde.append(product_info2[0].text)
    except:
        product_recallbgnde.append(" ")

    
    try:
        # 리콜 종료일
        product_info2 = soup.find_all('recallendde')
        product_recallendde.append(product_info2[0].text)
    except:
        product_recallendde.append(" ")
    
    try:
        # 리콜 절차 정보
        product_info2 = soup.find_all('recallprocssinfo')
        product_recallprocssinfo.append(product_info2[0].text)
    except:
        product_recallprocssinfo.append(" ")
    
    try:
        # 문의처 / 사업자 주소
        product_info2 = soup.find_all('recallentrpsinfo')
        product_recallentrpsinfo.append(product_info2[0].text)
    except:
        product_recallentrpsinfo.append(" ")
    
    try:
        # 정보 출처 기관
        product_info2 = soup.find_all('infoorigininstt')
        product_infoorigininstt.append(product_info2[0].text)
    except:
        product_infoorigininstt.append(" ")
    
    try:
            # 정보 출처 URL

        product_info2 = soup.find_all('infooriginurl')
        product_infooriginurl.append(product_info2[0].text)
    except:
        product_infooriginurl.append(" ")
    
    try:
            # 정보 생성 기관
        product_info2 = soup.find_all('infocreatinstt')
        product_infocreatinstt.append(product_info2[0].text)
    except:
        product_infocreatinstt.append(" ")
    
    try:
            # 정보 생성 URL
        product_info2 = soup.find_all('infocreaturl')
        product_infocreaturl.append(product_info2[0].text)
    except:
        product_infocreaturl.append(" ")

Product_df_01 = pd.DataFrame({
    '제품명' : product_name,
    '제조사' : product_makr,
    '사업자명' : product_bsnmnm,
    '제조기간' : product_mnfcturpd,
    '모델명정보' : product_modlnminfo,
    '제조번호' : product_mnfcturnoinfo,
    '표준바코드' : product_stdbrcd,
    '유통기한일자' : product_distbtmlmtde,
    '허가번호' : product_prmisnno,
    '의료기기분류번호' : product_mdlpclno,
    '제품상세내용' : product_aditfield13,
    '기타정보' : product_etcinfo,
    '주요판매처' : product_mainsleoffic,
    '결함내용' : product_shrtcomcn,
    '리콜구분' : product_recallse,
    '리콜공표시작일' : product_recallpublictbgnde,
    '리콜공표만료일' : product_recallpublictendde,
    '위해원인결과' : product_injrycauseresult,
    '위해취약대상자' : product_injryfrgltytrgter,
    '위해성등급' : product_hrmflgrad,
    '사고내용' : product_acdntcn,
    '소비자행동요령' : product_cnsmrghvrtips,
    '취급주의사항' : product_trtmntatpn,
    '리콜시작일' : product_recallbgnde,
    '리콜종료일' : product_recallendde,
    '리콜절차정보' : product_recallprocssinfo,
    '사업자주소' : product_recallentrpsinfo,
    '정보출처기관' : product_infoorigininstt,
    '정보출처URL' : product_infooriginurl,
    '정보생성기관' : product_infocreatinstt,
    '정보생성URL' : product_infocreaturl
})

Product_df_01.to_excel("./공정거래위원회_자동차_리콜정보.xlsx", encoding="cp949")

###
