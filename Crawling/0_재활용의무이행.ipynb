# %%
import pandas as pd
import numpy as np
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time

# %% [markdown]
# #### 포장재(일반)
# www.pkg.or.kr
#
# - 업체명, 사업자번호, 인증기간, 연장기한, 인증대상 포장재
#
# - 메일로 수집이 이뤄져야함

# %% [markdown]
# #### 재활용(농산물)

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("http://www.karc.or.kr/guide/member/index.php?boardid=member&sk=&sw=&category=&etc_1=Y&etc_2=&etc_3=&offset=0")
driver.implicitly_wait(20)


col_1=[]
col_2=[]
col_3=[]
Counts = 1
try:
    for k in range(1,12):
        if k == 1:
            for j in range(2,12):
                if j == 11:
                    for i in range(1,11):
                        # 업체명
                        col_11 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[1]".format(i)).text
                        # 주소
                        col_22 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[2]".format(i)).text
                        # 배출량
                        col_33 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[3]".format(i)).text

                        col_1.append(col_11)
                        col_2.append(col_22)
                        col_3.append(col_33)

                        print(Counts,".",col_11,col_22,col_33)
                        Counts +=1
                    driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[5]/a[2]").click()
                else:
                    for i in range(1,11):
                        # 업체명
                        col_11 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[1]".format(i)).text
                        # 주소
                        col_22 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[2]".format(i)).text
                        # 배출량
                        col_33 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[3]".format(i)).text

                        col_1.append(col_11)
                        col_2.append(col_22)
                        col_3.append(col_33)

                        print(Counts,".",col_11,col_22,col_33)
                        Counts +=1
                    driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[5]/span[{}]/a".format(j)).click()
            print(k)
            time.sleep(2)
        else:
            for j in range(2,12):
                if j == 11:
                    for i in range(1,11):
                        # 업체명
                        col_11 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[1]".format(i)).text
                        # 주소
                        col_22 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[2]".format(i)).text
                        # 배출량
                        col_33 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[3]".format(i)).text

                        col_1.append(col_11)
                        col_2.append(col_22)
                        col_3.append(col_33)

                        print(Counts,".",col_11,col_22,col_33)
                        Counts +=1
                    driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[5]/a[3]").click()
                else:
                    for i in range(1,11):
                        # 업체명
                        col_11 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[1]".format(i)).text
                        # 주소
                        col_22 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[2]".format(i)).text
                        # 배출량
                        col_33 = driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[4]/div/table/tbody/tr[{}]/td[3]".format(i)).text

                        col_1.append(col_11)
                        col_2.append(col_22)
                        col_3.append(col_33)

                        print(Counts,".",col_11,col_22,col_33)
                        Counts +=1
                    driver.find_element_by_xpath("/html/body/div/div[3]/div/div[2]/div[2]/div/div[5]/span[{}]/a".format(j)).click()
            print(k)
            time.sleep(2)
except:
    print("종료")
    
df_01 = pd.DataFrame()
df_01['지역'] = col_1
df_01['인증대상'] = col_2
df_01['업체명'] = col_3

driver.close()
# Out:
# 1 . 전남 김발장 주식회사삼진
# 2 . 부산 양식용부자 진일산업
# 3 . 경북 양식용부자 전진산업
# 4 . 전남 양식용부자 화양수지주식회사
# 5 . 전남 양식용부자 죽산에스피주식회사
# 6 . 전남 양식용부자 주식회사제이에스수지
# 7 . 전남 양식용부자 주식회사대광
# 8 . 전남 양식용부자 주식회사국제화학
# 9 . 충남 곤포사일리지 우양폴리머(주)
# 10 . 경남 PP마대 포장재 (주)승리
# 11 . 경남 PP마대 포장재 호현바이오
# 12 . 부산 PP마대 포장재 주식회사주명
# 13 . 서울 PP마대 포장재 (주)오미아코리아
# 14 . 경남 PP마대 포장재 (주)피제이켐텍
# 15 . 대구 PP마대 포장재 (주)동광상사
# 16 . 울산 PP마대 포장재 (주)유니드(울산)
# 17 . 충북 PP마대 포장재 (주)농부와콩
# 18 . 충북 PP마대 포장재 거상
# 19 . 부산 PP마대 포장재 길로무역주식회사
# 20 . 서울 PP마대 포장재 한국엔지니어링플라스틱(주)
# 21 . 전북 PP마대 포장재 농업회사법인(주)다원에프에스
# 22 . 충남 PP마대 포장재 (주)수암
# 23 . 울산 PP마대 포장재 효성첨단소재(주)울산공장
# 24 . 울산 PP마대 포장재 효성티앤씨(주)울산공장
# 25 . 부산 PP마대 포장재 기성전선(주)
# 26 . 전북 PP마대 포장재 (주)삼양사전주공장
# 27 . 세종 PP마대 포장재 아세아제지(주)세종공장
# 28 . 부산 PP마대 포장재 (주)대진지피아이
# 29 . 경기 PP마대 포장재 (주)지비오
# 30 . 경남 PP마대 포장재 (주)태승뷰티산업
# 31 . 경기 PP마대 포장재 (주)정우정밀화학
# 32 . 서울 PP마대 포장재 에쓰오일(주)
# 33 . 부산 PP마대 포장재 대한수산(주)
# 34 . 서울 PP마대 포장재 (주)경성이엔티
# 35 . 울산 PP마대 포장재 (주)금정
# 36 . 울산 PP마대 포장재 고도화학주식회사
# 37 . 울산 PP마대 포장재 (주)케이피켐텍
# ...

# %% [markdown]
# #### 포장재(윤활유) / 윤활유
# www.kloia.or.kr
#
# - 재활용동향 > 폐빈용기 > 재활용사업 공제조합회원
# - 업체명, 대표자, 주소, 전화번호

# %%
# 윤활유
df_1 = pd.read_html('http://www.kloia.or.kr/trend/trend_sub03.php',header=0, encoding='cp949')[3]
df_2 = pd.read_html('http://www.kloia.or.kr/trend/trend_sub03_1.php',header=0, encoding='cp949')[3]
df_3 = pd.read_html('http://www.kloia.or.kr/trend/trend_sub03_2.php',header=0, encoding='cp949')[3]

df_1 = df_1.iloc[0::2,0::2]
df_1 = df_1.iloc[1:,1:5].reset_index().iloc[:,1:]
df_1.columns = ['업체명','대표자','주소','전화번호']
df_2 = df_2.iloc[0::2,0::2]
df_2 = df_2.iloc[1:,1:5].reset_index().iloc[:,1:]
df_2.columns = ['업체명','대표자','주소','전화번호']
df_3 = df_3.iloc[0::2,0::2]
df_3 = df_3.iloc[1:,1:5].reset_index().iloc[:,1:]
df_3.columns = ['업체명','대표자','주소','전화번호']
df_02 = pd.concat([df_1,df_2,df_3],axis=0)
df_02 = df_02.dropna()


try:
    df_4 = pd.read_html('http://www.kloia.or.kr/trend/trend_sub03_2.php',header=0, encoding='cp949')[3]
    df_4 = df_4.iloc[0::2,0::2]
    df_4 = df_4.iloc[1:,1:5].reset_index().iloc[:,1:]
    df_4.columns = ['업체명','대표자','주소','전화번호']
    
    df_02 = pd.concat([df_1,df_2,df_3,df_4],axis=0)
    df_02 = df_02.dropna()
    
except:
    print("새로생긴칸이 없음")

# %%
# 윤활유(포장재)
df_03 = pd.read_html('http://www.kloia.or.kr/trend/trend02_sub03.php',header=0, encoding='cp949')[3]
df_03 = df_1.iloc[0::2,0::2]
df_03 = df_1.iloc[1:,0:4].reset_index().iloc[:,1:]
df_03.columns = ['업체명','대표자','주소','전화번호']

# %% [markdown]
# #### 타이어
# www.kotma.or.kr
#
# - 환경사업 > 재활용관련업체 > 공제조합원 현황
# - 업체명, 대표자, 전화번호, 주소

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("http://www.kotma.or.kr/waste-tire-recycling/waste-tire-recycling-companies")
driver.implicitly_wait(20)

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

needs = soup.find_all('div',{'class':'list__box'})
a=[]
for i in range(len(needs)):
    a.append(needs[i].text.split('\n')[1])
    a.append(needs[i].text.split('\n')[7])
    a.append(needs[i].text.split('\n')[11])
    a.append(needs[i].text.split('\n')[15])

df_04 = pd.DataFrame()
df_04['업체명'] = a[0::4]
df_04['대표자'] = a[1::4]
df_04['전화번호'] = a[2::4]
df_04['주소'] = a[3::4]

driver.close()

# %% [markdown]
# #### 형광등
# www.klrc.or.kr
#
# - 회원사 > 회원사 현황
# - 업체명, 대표자, 사업장주소

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("http://www.klrc.or.kr/bbs/member_company.html")
driver.implicitly_wait(20)

html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

need1 = soup.find_all("td",{'class' : 'co01'})
need2 = soup.find_all("td",{'class' : 'co02'})

b = []
for i in need2:
    b.append(i.text)
a = []
for i in need1:
    a.append(i.text)
    
df_05 = pd.DataFrame()
df_05['업체명'] = a[1::3]
df_05['대표자'] = a[2::3]
df_05['주소'] = b
driver.close()

# %% [markdown]
# #### 전지류
# www.kbra.net
#
# - 회원현황 > 정회원
# - 업체명, 대표자, 사업장주소, 홈페이지

# %%
df_06 = pd.read_html('http://www.kbra.net/sub/sub02_02.php',header=0)[1].iloc[:,1:4]

driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("http://www.kbra.net/sub/sub02_02.php")
driver.implicitly_wait(20)
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
need1 = soup.find_all("a",{'class' : 'link'})

e=[]
for j in need1:
    e.append(j['href'])
df_06['홈페이지'] = e[:df.shape[0]]
driver.close()
df_06 = df_06.rename(columns = {'지역':'주소'})

# %%
col = ['구분','업체명','대표자','지역','주소','전화번호','사업자번호','인증일자','인증만료일자','인증대상','홈페이지','KED코드']
fin = pd.DataFrame(columns=col)
final = pd.concat([fin,df_01,df_02,df_03,df_04,df_05,df_06],join='outer')
final.to_excel(r"C:Users/KED_Internet/바탕화면/ESG/monthly_data/ESG_재활용의무_{}_{}_{}.xlsx".
              format(time.localtime()[0],time.localtime()[1],time.localtime()[2]),index=None)
