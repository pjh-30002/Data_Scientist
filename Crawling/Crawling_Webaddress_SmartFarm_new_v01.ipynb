# %%
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time
pd.set_option('display.max_row', 20)
pd.set_option('display.max_columns', 100)

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smartfarmkorea.net/company/companyInfo.do?menuId=M01020210")

# %%
res = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[1]/td[8]").text

# %%
print(res)
# Out:
# 울산광역시 울주군 온산읍 신온7길 79-9

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smartfarmkorea.net/company/companyInfo.do?menuId=M01020210")

Last_n = []
Last_p = []
Last_a = []
for i in range(1,11):
    #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
    #driver.implicitly_wait(10)
    #name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
    #person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
    address = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[8]".
                                          format(i)).text
    
    # 목록으로 돌아가기
    #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[3]/div/a").click()
    try:
        driver.back()
    except:
        driver.back()
    driver.implicitly_wait(10)
    time.sleep(1)
    Last_n.append(name)
    Last_p.append(person)
    #Last_a.append(address)
    print(name, person, address)
# Out:
# 홍익네트웍스주식회사 최용실
# 호현테스트 ㅇ
# 혜성테크 최혜영
# 현대축산기계주식회사 농업회사법인 홍도영
# 현대공조(주) 강성대
# 한화테크윈 안순홍
# 한진시스템 한이진
# 한라테크주식회사 홍성언
# 한라자동화 양태호
# 한국축산기기 김장근

# %%
for i in range(1,11):
    try:
        driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
        #driver.implicitly_wait(10)
        name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
        person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
        #address = driver.find_element_by_xpath("//*[@id="cpAddr"]").text

        # 목록으로 돌아가기
        #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[3]/div/a").click()
        try:
            driver.back()
        except:
            driver.back()
        driver.implicitly_wait(10)
        time.sleep(1)
        Last_n.append(name)
        Last_p.append(person)
        #Last_a.append(address)
        print(name, person, address)
    except:
        Last_n.append(" ")
        Last_p.append(" ") 
        print(i)
# Out:
# 주식회사 케이에프농업개발 박철수
# 주식회사 중부시스템 남기상
# 주식회사 제이유씨엔씨 김동혁
# 주식회사 제이에스바이오 이정석
# 주식회사 제우스 김한상
# 주식회사 정림 임재언
# 주식회사 일루베이션 원형필
# 주식회사 유지아이티정보 김은억
# 주식회사 유비스마트 신언봉
# 주식회사 유로젠 손준구

# %%
# 다음페이지로
for j in range(1,10):
    # 10개 리스트 긁어오기
    for i in range(1,11):
        try:
            driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
            #driver.implicitly_wait(10)
            name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
            person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
            #address = driver.find_element_by_xpath("//*[@id="cpAddr"]").text

            # 목록으로 돌아가기
            #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[3]/div/a").click()
            try:
                driver.back()
            except:
                driver.back()
            driver.implicitly_wait(10)
            time.sleep(1)
            Last_n.append(name)
            Last_p.append(person)
            #Last_a.append(address)
            print(name, person, address)
        except:
            Last_n.append(" ")
            Last_p.append(" ") 
            print(i)
    driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[3]/a[{}]".format(j)).click()
# Out:
# 1
# (주)유닉스이엔지 최승현
# (주)월드씨앤에스 김용광
# (주)원인터내셔널 원유중
# (주)우성하이텍 이해완
# (주)우리농장연구소 김용주
# (주)우리농자재 전병관
# (주)와이즈맥스 김인규
# (주)와이더블유벤쳐스 허갑열
# (주)영도시큐리티 김강민
# (주)엠이티글로벌 주준열
# (주)엠알티 선기주
# (주)에프에이멘 송태환
# (주)에이케어 이영호
# (주)에이앤에스코리아 최정열
# (주)에스티엠 엄기석
# (주)에버비젼 조광종
# (주)에그텍 윤택진
# (주)어니언커뮤니케이션즈 권준성
# (주)애그리로보텍 함영화
# (주)알앤에스랩 이상엽
# 2
# (주)아이티엑스에이아이 박상열, 유건상
# (주)아이디스 김영달
# (주)아성온 최낙민
# (주)씨아이티이엔지 송경순
# (주)씨아이티시스템 박호인
# (주)씨넥스존 김광일
# (주)시스웍스 임종철
# (주)스카이통신 박창선
# (주)스마트제어계측 김미화
# (주)스마트정보통신 김형주
# (주)송강지엘씨 김영철
# (주)소프트아쿠아 장희정
# (주)성진시스템 김성환
# (주)선진환경산업 변금희
# (주)서원농축산 이상근
# (주)샤론테크 장윤환
# (주)샘스 이도향
# (주)상일테크 정상택
# (주)삼호씨티 김태삼
# (주)삼창이엔지 허구범
# (주)삼우 안광덕
# (주)삼신씨엔에스 정명호
# (주)부성기연 김길식
# (주)보람 가보람
# (주)바이오라인 임정민
# (주)미농테크 김용국
# (주)무진테크노 박광선
# (주)모모스 임준모
# (주)모리아팜 김상균
# (주)맨유바이오 윤광근
# (주)로비텍 박수우
# (주)로드반 김형준
# (주)라인인포 서암석
# (주)라이브텍 김기웅
# (주)라이브엠 김희정
# (주)디엔디전자 서순기
# (주)드림씨에스씨 박창진
# (주)두현 서정환
# (주)동조 이용구
# (주)동양테크윈 김지평
# (주)동림건설 차재철
# (주)더던 이정주
# (주)대흥에어포그 강경혜
# (주)대은계전 고휴환
# (주)대성기연 김정욱
# (주)대로 황혜영
# ...

# %%
# 클릭이 안되는 로우가 존재하여 그 부분은 수기로 작성해야함클릭이 안되는 로우가 존재하여 그 부분은 수기로 작성해야함
# 다음 장으로
for k in range(1,4):
    # 다음페이지로
    for j in range(1,10):
        # 10개 리스트 긁어오기
        for i in range(1,11):
            try:
                driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
                #driver.implicitly_wait(10)
                name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
                person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
                #address = driver.find_element_by_xpath("//*[@id="cpAddr"]").text

                # 목록으로 돌아가기
                #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[3]/div/a").click()
                try:
                    driver.back()
                except:
                    driver.back()
                driver.implicitly_wait(10)
                time.sleep(1)
                Last_n.append(name)
                Last_p.append(person)
                #Last_a.append(address)
                print(name, person, address)
            except:
                Last_n.append(" ")
                Last_p.append(" ") 
                print(i)
        driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[3]/a[{}]".format(j)).click()
    driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[4]/a").click()
    print(k)
# Out:
# 1
# 주식회사 영진 조영식
# 3
# 주식회사 엔퓨텍 이화용,조해연
# 주식회사 엔엔케이 김민조
# 주식회사 에쿨텍 김민재
# 주식회사 에이치제이나인 윤정구
# 주식회사 에스엠엔지니어링 윤선민
# 주식회사 아이오티팜 농업회사법인 정지희
# 주식회사 실티 신일현
# 주식회사 신우이엔지 하민호
# 주식회사 신예 최재열
# 주식회사 스카이티제이 문태수
# 4
# 주식회사 소하테크 윤득중
# 주식회사 세티 허용준
# 주식회사 세움건설 장석용
# 주식회사 성광이엔지 이만춘
# 주식회사 선운정보통신 유영대
# 주식회사 새암건설 공종학
# 주식회사 새그린 이현석
# 주식회사 비앤에스 신경인
# 주식회사 비바엔에스 김영식
# 주식회사 부성 이보웅,이용복
# 주식회사 백송 윤정덕
# 주식회사 명천 정복순
# 주식회사 리뉴바이오 이영로
# 주식회사 라인통신 김연일
# 주식회사 드림스테이션 김정희
# 주식회사 두리 김동호
# 주식회사 동성코코팬 이희태
# 주식회사 동부그린테크 정종수
# 주식회사 대흥금속 이상복
# 주식회사 대일아이씨티 안성찬
# 주식회사 대경정보통신 김지호
# 주식회사 다운 최영경
# 주식회사 길소프트 김광형
# 주)편한소 유재복
# 주)주일테크 염호
# 주)제이씨텍 정태준
# 주)우양코퍼레이션 김진홍
# 조은나라(주) 정재용
# 제트텍 하민주
# 제일에이텍 최승주
# 제이엔씨네트웍스(주) 정광철
# 제이에이(JA)테크 방선미
# 제이비파워텍 김옥금
# 정글인터네셔널 성현준
# 절벽의오른쪽 김종영
# 전국축산기기 김정범
# 재성하이텍 한 지 호
# 임실종합축산 김예순
# 일신 이선희
# 인프로 최승혁
# 인포뱅크(주) 박태형
# 이천계기서부영업소 이경용
# 이젠365 안정립
# 이오기술 이해정
# 이엠에스 김창주
# 이십일세기이엔지 오원식
# 이삭이엔지 유현호
# 이레ENG 손성렬
# 은현낙농 염대성
# 유한회사 제이엠하이텍 민선업
# 유한회사 애니팜티에스 성명환
# 유한회사 동방이노베이션 김준식
# 유한회사 대도 권봉주
# 위팜스주 이춘호
# ...

# %%
df = pd.DataFrame()
df['업체명'] = Last_n
df['대표자'] = Last_p
df.to_excel("./farm_new_3.xlsx")

# %%
df
# Out:
#                    업체명  대표자
# 0           홍익네트웍스주식회사  최용실
# 1                호현테스트    ㅇ
# 2                 혜성테크  최혜영
# 3    현대축산기계주식회사 농업회사법인  홍도영
# 4              현대공조(주)  강성대
# ..                 ...  ...
# 465           (유)린캔패스트  조재선
# 466       (유)대산테크 (양계)  김영관
# 467           (유) 태웅건설  김동희
# 468              태림이엔지  임석환
# 469
#
# [470 rows x 2 columns]

# %%
# 다음페이지로    
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[1]/a[1]").click()
driver.implicitly_wait(10)

try:
    for j in range(2,9):
        for i in range(1,11):
            driver.implicitly_wait(10)
            driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
            driver.implicitly_wait(10)
            #name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
            #person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
            #address = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[2]/tbody/tr[2]/td/input[3]").text
            #address = soup.find('input',{'name':'hidden'}).get('value')

            try:
                driver.back()
            except:
                driver.back()
            driver.implicitly_wait(10)
            time.sleep(1)
            Last_n.append(name)
            Last_p.append(person)
            #Last_a.append(address)
            print(name, person, address)
        # 다음페이지로    
        driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[2]/a[{}]".format(j)).click()
        driver.implicitly_wait(10)
    driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[3]/a").click()
except:
    print("끝")

# %%
Last_a
# Out:
# ['', '', '', '', '', '', '', '', '', '']

# %%
df = pd.DataFrame()
df['업체명'] = Last_n
df['대표자'] = Last_p
df['주소'] = Last_a
df.to_excel("./farm_11.xlsx")

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smartfarmkorea.net/company/list.do")

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smartfarmkorea.net/company/list.do")
time.sleep(1)
Last_n = []
Last_p = []
Last_a = []
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[2]/a").click()
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[4]/a").click()
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[4]/a").click()
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[4]/a").click()
driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[4]/a").click()

for k in range(2,4):
    for j in range(1,10):    
        for i in range(1,11):
            driver.implicitly_wait(20)
            driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[3]/table/tbody/tr[{}]/td[3]".format(i)).click()
            
            
            driver.implicitly_wait(20)
            name = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[1]/table/tbody/tr[2]/td").text
            person = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[1]/table/tbody/tr[6]/td[1]").text
            address = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[1]/table/tbody/tr[7]/td").text
            # 목록으로 돌아가기
            #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[2]/div[3]/div/a").click()
            try:
                driver.back()
            except:
                driver.back()           

            Last_n.append(name)
            Last_p.append(person)
            Last_a.append(address)
            print(name, person, address)
        # 다음페이지로    
        driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[3]/a[{}]".format(j)).click()
        driver.implicitly_wait(20)
    # 다음장으로
    driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/div[3]/div[4]/span[4]/a").click()
    print(k)
# Out:
# 이십일세기이엔지 오원식 경기도 하남시 감초로69번길 29-131층
# (주)청오엔지니어링 권오숙 대전광역시 대덕구 대화로32번길 60-9대전광역시 대덕구 대화로32번길 60-9
# 메디앙시스템 박기선 전라북도 전주시 완산구 아중로 33(재)전주정보문화산업진흥원 문화산업지원센터 205호
# (주)애그리로보텍(양계) 함영화 경기도 이천시 부발읍 신아로 58애그리로보텍
# (주)애그리로보텍(양돈) 함영화 경기도 이천시 부발읍 신아로 58애그리로보텍
# 한길무역상사 김옥경 경기도 광명시 아방리1길 24-14(노온사동)
# COMIX(코믹스) 이인숙 충청남도 논산시 대학로 121B108(내동, 건양대학 산업협력관)
# (주)애그리로보텍(낙농) 함영화 경기도 이천시 부발읍 신아로 58애그리로보텍
# (주)애그리로보텍(한우) 함영화 경기도 이천시 부발읍 신아로 58애그리로보텍
# (주)한진 정연자 경상남도 고성군 영오면 월아산로136번길 23(주)한진농공
# 밀전자 이병영 서울특별시 금천구 시흥대로 9732동 3층 345호(시흥동, 시흥산업용재유통센터)
# (주)에이케어 이영호 경기도 군포시 대야2로 35116호
# 태창바이오(주) 전효준 전라남도 담양군 담양읍 에코길 9태창바이오(주)
# 성우MD 장덕상 경기도 김포시 양촌읍 구래로42번길 47성우MD
# 이삭이엔지 유현호 경기도 양주시 광적면 광적로326번길 159-15이삭ENG
# (주)대은계전 고휴환 제주특별자치도 제주시 첨단로8길 86-2(영평동)
# 진안테크 김용원 경상북도 상주시 삼백로 117진안테크
# 그리심산업 이명섭 대전광역시 대덕구 오정로99번길 16-7오정동
# 미래냉열산업 이규도 경기도 화성시 팔탄면 노하길116번길 202노하리 557-8
# 이노비스 김춘수 충청남도 천안시 동남구 병천면 충절로 1600TBI 302호
# 엘리스일렉트로닉스(농업회사법인 엘리스더팜) 조만수 경기도 고양시 일산동구 경의로 309303호
# 유) 봉동신화 김문구 전라북도 완주군 봉동읍 봉동로 4봉동신화
# ...

# %%
df_1 = df.loc[:99]
df_1.to_excel("./farm_1.xlsx")

# %%
df = pd.DataFrame()
df['업체명'] = Last_n
df['대표자'] = Last_p
df['주소'] = Last_a
df
df.to_excel("./farm_3.xlsx")

# %%
df = pd.read_excel("./farm_last.xlsx")
df
# Out:
#      Unnamed: 0             업체명  대표자  \
# 0             1         지현테크놀로지  심승원
# 1             2        (주)송강지엘씨  김영철
# 2             3        (주)현성인포컴  박홍수
# 3             4      동양정보산업주식회사  장정숙
# 4             5      태창축산종합기술개발  인창언
# ..          ...             ...  ...
# 667         668    주식회사 어비트(양계)  반상형
# 668         669          퍼펙트시스템  나경성
# 669         670  (주)가농인터내셔날(양계)  김효찬
# 670         671  주식회사 유로시스템(양계)  홍종표
# 671         672         지엔에스코리아  지인규
#
#                                                  주소  Unnamed: 4  Unnamed: 5  \
# 0               충청북도 청주시 서원구 현도면 시목외천로 171-5지현테크놀로지         NaN         NaN
# 1    경기도 성남시 중원구 사기막골로 124비즈센터 415(본사) / B114호 (공장)         NaN         NaN
# 2               서울특별시 용산구 청파로 12517가138호(한강로동,나진상가)         NaN         NaN
# 3                 충청북도 진천군 진천읍 중앙서로 43-10동양정보산업주식회사         NaN         NaN
# 4                     충청남도 홍성군 홍북읍 홍학로 88113동 1501호         NaN         NaN
# ...

# %%
len(set(df['업체명']))
# Out:
# 582

# %% [markdown]
# #### 주소

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smartfarmkorea.net/company/companyInfo.do?menuId=M01020210")
driver.implicitly_wait(20)
Last_n = []
Last_p = []
Last_a = []
for i in range(1,11):
    address = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[8]".format(i)).text
    Last_a.append(address)
    print(address)
# Out:
# 울산광역시 울주군 온산읍 신온7길 79-9
# 경기도 수원시 팔달구 수성로 92
# 인천광역시 동구 만석부두로13번길 42
# 경상북도 칠곡군 지천면 송정도당길 113
# 울산광역시 북구 매곡산업로 35
# 경기도 성남시 분당구 판교로319번길 6
# 경기도 안양시 동안구 시민대로365번길 40
# 제주특별자치도 서귀포시 남원읍 일주동로 7169
# 제주특별자치도 서귀포시 대정읍 추사로 11-6
# 경기도 남양주시 경강로 65-19

# %%
for i in range(1,11):
    address = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[8]".format(i)).text
    Last_a.append(address)
    print(address)
# Out:
# 경상남도 창원시 의창구 창원대로18번길 22
# 충청북도 청주시 흥덕구 1순환로436번길 22
# 서울특별시 용산구 청파로 125
# 전라남도 장성군 남면 나노산단5로 57
# 제주특별자치도 제주시 첨단로 175
# 충청남도 아산시 영인면 신봉길 25
# 전라북도 전주시 덕진구 기지로 72
# 충청북도 청주시 상당구 영운천로153번길 37
# 경기도 성남시 중원구 갈마치로 234
# 서울특별시 구로구 디지털로31길 53

# %%
try:
    for k in range(1,10):
        for j in range(1,9):
            for i in range(1,11):
                #driver.implicitly_wait(10)
                #driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[7]".format(i)).click()
                #driver.implicitly_wait(10)
                #name = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[1]/td[1]").text
                #person = driver.find_element_by_xpath("/html/body/div[1]/div[4]/div/div[2]/div[2]/div[3]/form[1]/div[2]/table[1]/tbody/tr[2]/td").text
                address = driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[1]/table/tbody/tr[{}]/td[8]".format(i)).text
                Last_a.append(address)
                print(address)
            # 다음페이지로    
            driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[3]/a[{}]".format(j)).click()

            driver.implicitly_wait(10)
        driver.find_element_by_xpath("/html/body/div/div[4]/div/div[2]/div[2]/form[1]/div[2]/span[4]/a").click()
        
    print(k)
except:
    print("끝")
# Out:
# 서울특별시 송파구 법원로9길 26
# 충청남도 아산시 온주길26번길 33-3
# 경상남도 김해시 생림면 나전로137번길 44
# 경기도 광주시 초월읍 독고개길 30
# 경기도 화성시 향남읍 토성로 352
# 충청남도 공주시 유구읍 고재동길 8-11
# 부산광역시 강서구 공항로767번다길 30-4
# 충청북도 청주시 흥덕구 직지대로 530
# 충청남도 논산시 채운면 채운로 398-8
# 경기도 고양시 일산동구 지영로 67
# 전라남도 담양군 대전면 갈전길 22
# 충청남도 천안시 동남구 성남면 봉양1길 205-20
# 경기도 의정부시 녹양로18번길 54
# 경기도 남양주시 진접읍 남가로131번길 1-1
# 서울특별시 노원구 노원로15길 10
# 경기도 이천시 부발읍 신아로 58
# 대구광역시 수성구 수성로14길 35
# 전라북도 정읍시 황토현로 970
# 전라북도 고창군 고수면 고수농공단지길 42
# 경상남도 합천군 청덕면 동부로 1748-1
# 전라북도 전주시 덕진구 삼례로 116
# 강원도 춘천시 동광길 7-1
# 서울특별시 강남구 논현로114길 11
# 인천광역시 남동구 남동대로155번길 80
# 대구광역시 서구 문화로 22-16
# 경상남도 고성군 하이면 덕명5길 44
# 경기도 성남시 중원구 갈마치로 176
# 충청북도 청주시 청원구 오창읍 양청택지로 118
# 경기도 성남시 중원구 갈마치로 314
# 충청북도 보은군 장안면 장재로 8
# 경기도 화성시 송산면 송산포도로 283
# 경기도 포천시 신북면 호국로 2039-183
# 충청남도 아산시 신창면 학성로 82
# 제주특별자치도 제주시 오복7길 29
# 경상남도 거제시 거제중앙로10길 17
# 인천광역시 서구 보도진로42번길 22
# 경기도 수원시 팔달구 수성로 92
# 경기도 부천시 길주로 221
# 충청남도 금산군 추부면 추풍로 344
# 대전광역시 유성구 복용남로 67-1
# 전라북도 전주시 완산구 천잠로 303
# 대구광역시 동구 효신로 62
# 경기도 광주시 곤지암읍 신만로 123
# ...

# %%
df_a = pd.DataFrame()
df_a['주소'] = Last_a
df_a
df_a.to_excel("./farm_a.xlsx")
