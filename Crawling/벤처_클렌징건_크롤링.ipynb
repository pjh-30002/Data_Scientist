# %%
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time
pd.set_option('display.max_row', 20)
pd.set_option('display.max_columns', 100)

# %%
cols1 = []
cols2 = []
cols3 = []
cols4 = []
cols5 = []
cols6 = []
cols7 = []
cols8 = []
cols9 = []
cols10 = []
cols11 = []
cols12 = []
cols13 = []
cols14 = []
counts = []

# %%
data = pd.read_excel("./6월/202106월 추가 기업리스트.xlsx")

# %%
data['사업자번호'] = data['사업자번호'].astype('object')

# %%
nn = data['사업자번호']

# %%
nn
# Out:
# 0       5210300570
# 1       6108630697
# 2       1448104023
# 3       1198678859
# 4       4028169316
#            ...
# 2421    5518700474
# 2422    6178132880
# 2423    6648800461
# 2424    6948100798
# 2425    8368101450
# Name: 사업자번호, Length: 2426, dtype: object

# %%
# 크롤링 시작
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://www.smes.go.kr/venturein/pbntc/searchVntrCmp")
driver.implicitly_wait(20)
time.sleep(10)

# %%
for j in range(len(nn)):
    elem = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div[2]/form/div/div[1]/div[3]/input")
    elem.send_keys(nn[j])
    time.sleep(3)
    driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div[2]/form/div/div[3]/a").click()
    driver.implicitly_wait(20)
    time.sleep(1)

    try:        
        driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div[2]/table/tbody/tr/td[2]/a").click()
        print("현재 진행 상황 : {}.{}".format(j,nn[j]))
    except:
        print("목록에없는사항 : {}.{}".format(j,nn[j]))
        cols1.append(col1)
        cols2.append(col2)
        cols3.append(col3)
        cols4.append(col4)
        cols5.append(col5)
        cols6.append(col6)
        cols7.append(col7)
        cols8.append(col8)
        cols9.append(col9)
        cols10.append(col10)
        cols11.append(col11)
        cols12.append(col12)
        cols13.append(col13)
        cols14.append(col14)
        
        elem = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div[2]/form/div/div[1]/div[1]/input")
        elem.clear()
        continue
    driver.implicitly_wait(20)
    time.sleep(1)
    # 일반정보 수집
    col1 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[1]/td").text
    col2 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[2]/td[1]").text
    col3 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[2]/td[2]").text
    col4 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[3]/td[1]").text
    col5 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[3]/td[2]").text
    col6 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[4]/td[1]").text
    col7 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[4]/td[2]").text
    col8 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[1]/table/tbody/tr[5]/td").text
    cols1.append(col1)
    cols2.append(col2)
    cols3.append(col3)
    cols4.append(col4)
    cols5.append(col5)
    cols6.append(col6)
    cols7.append(col7)
    cols8.append(col8)


    driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/ul/li[4]").click()
    driver.implicitly_wait(20)
    time.sleep(1)
    try:
        a = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody").text
        co = a.count("\n")

        # 벤처기업 확인서
        col9 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[2]".format(co+1)).text
        col10 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[3]".format(co+1)).text
        col11 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[4]".format(co+1)).text
        col12 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[5]".format(co+1)).text
        col13 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[6]".format(co+1)).text
        col14 = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[1]/div[4]/div[2]/div[2]/table/tbody/tr[{}]/td[7]".format(co+1)).text

        cols9.append(col9)
        cols10.append(col10)
        cols11.append(col11)
        cols12.append(col12)
        cols13.append(col13)
        cols14.append(col14)
    except:
        cols9.append("")
        cols10.append("")
        cols11.append("")
        cols12.append("")
        cols13.append("")
        cols14.append("")

    driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div[2]/a").click()
    driver.implicitly_wait(20)
    time.sleep(3)
    elem = driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div[2]/form/div/div[1]/div[1]/input")
    elem.clear()
    time.sleep(1)
# Out:
# 현재 진행 상황 : 0.5210300570
# 현재 진행 상황 : 1.6108630697
# 현재 진행 상황 : 2.1448104023
# 현재 진행 상황 : 3.1198678859
# 현재 진행 상황 : 4.4028169316
# 현재 진행 상황 : 5.3148130678
# 현재 진행 상황 : 6.1348737742
# 현재 진행 상황 : 7.1248601686
# 현재 진행 상황 : 8.1208807135
# 현재 진행 상황 : 9.4108196959
# 현재 진행 상황 : 10.5978801141
# 현재 진행 상황 : 11.1048656135
# 현재 진행 상황 : 12.1238156179
# 현재 진행 상황 : 13.1268614630
# 현재 진행 상황 : 14.6038184486
# 현재 진행 상황 : 15.6188116108
# 현재 진행 상황 : 16.1378159516
# 현재 진행 상황 : 17.3148602783
# 현재 진행 상황 : 18.5148123520
# 현재 진행 상황 : 19.6091597626
# 현재 진행 상황 : 20.3148617286
# 현재 진행 상황 : 21.3568800105
# 현재 진행 상황 : 22.1308632831
# 현재 진행 상황 : 23.5038165044
# 현재 진행 상황 : 24.8398100450
# 현재 진행 상황 : 25.3108125339
# 현재 진행 상황 : 26.5138155446
# 현재 진행 상황 : 27.6060316276
# 현재 진행 상황 : 28.8133000140
# 현재 진행 상황 : 29.1178131057
# 현재 진행 상황 : 30.1370396075
# 현재 진행 상황 : 31.6098141961
# 현재 진행 상황 : 32.1198662546
# 현재 진행 상황 : 33.7608100625
# 현재 진행 상황 : 34.1138149502
# 현재 진행 상황 : 35.1498600046
# 현재 진행 상황 : 36.1138668237
# ...

# %%
df = pd.DataFrame()
df['기업명'] = cols1
df['대표자'] = cols2
df['법인번호'] = cols3
df['업종'] = cols4
df['주생산품'] = cols5
df['사업자번호'] = cols6
df['본사전화번호'] = cols7
df['본사주소'] = cols8
df['벤처유형'] = cols9
df['발급일'] = cols10
df['유효기간'] = cols11
df['벤처확인번호'] = cols12
df['최초확인일'] = cols13
df['변경사항'] = cols14

# %%
df
# Out:
#                           기업명  대표자            법인번호                        업종  \
# 0                      (SM)소파  신설훈                          소파 및 기타 내장가구 제조업
# 1                 (농업회사법인)이노팜  한형숙  204611-*******               기타 시설작물 재배업
# 2                    153로지스틱스  강창현  110111-*******               기타 보관 및 창고업
# 3                   4S Mapper  이승호                    컴퓨터시스템 통합 자문 및 구축 서비스업
# 4            ADVENSTAR(어드벤스타)  김태구                  그 외 기타 달리 분류되지 않은 제품 제조업
# ...                       ...  ...             ...                       ...
# 2530  히치메드(HitchMED Co.,Ltd.)  유지상  110111-*******         응용 소프트웨어 개발 및 공급업
# 2531                   히트 인덕션  정기환  110111-*******              주방용 전기기기 제조업
# 2532                 힐링가든휴(休)  김현철                                  화훼작물 재배업
# 2533                    힐링시스템  이수웅  161511-*******           농업 및 임업용 기계 제조업
# 2534                   힐엔지니어링  우종열  180111-*******        건물 및 토목 엔지니어링 서비스업
#
# ...

# %%
df.to_excel("./벤처_클렌징건_v01_박주혁.xlsx")
