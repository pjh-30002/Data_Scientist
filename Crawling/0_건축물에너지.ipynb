# %%
import pandas as pd
import numpy as np
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time
pd.set_option('display.max_row', 20)
pd.set_option('display.max_columns', 100)

# %%
driver = webdriver.Chrome(executable_path= r'C:/Chromedrive/chromedriver')
driver.get("https://beec.energy.or.kr/BC/BC04/BC04_04_001.do")
driver.implicitly_wait(20)
# 2020년
#driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/form/fieldset/div/div/ul[2]/li[1]/select/option[2]").click()
#driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/form/fieldset/div/div/ul[2]/li[2]/input[2]").click()
col_1=[]
col_2=[]
col_3=[]
col_4=[]
col_5=[]
col_6=[]
col_7=[]
col_8=[]

Counts = 1
try:
    for k in range(1,71):
        if k == 1:
            for j in range(2,13):
                if j == 11:
                    print("skip")
                else:
                    for i in range(1,11):
                        # 업체명
                        col_11 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[2]/strong".format(i)).text
                        # 주소
                        col_22 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[3]".format(i)).text
                        # 배출량
                        col_33 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[4]".format(i)).text
                        # 자가매립량
                        col_44 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[5]".format(i)).text
                        # 이동량
                        col_55 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[6]".format(i)).text

                        col_66 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[7]".format(i)).text

                        col_77 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[8]".format(i)).text

                        col_88 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[9]".format(i)).text

                        col_1.append(col_11)
                        col_2.append(col_22)
                        col_3.append(col_33)
                        col_4.append(col_44)
                        col_5.append(col_55)
                        col_6.append(col_66)
                        col_7.append(col_77)
                        col_8.append(col_88)

                        print(Counts,".",col_11,col_22,col_33,col_44,col_55,col_66,col_77,col_88)
                        Counts +=1
                    driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[2]/div/div/a[{}]".format(j)).click()
                    driver.implicitly_wait(20)
                    time.sleep(3)
            print(k)
        else:
            for j in range(4,14):
                for i in range(1,11):
                    # 업체명
                    col_11 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[2]/strong".format(i)).text
                    # 주소
                    col_22 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[3]".format(i)).text
                    # 배출량
                    col_33 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[4]".format(i)).text
                    # 자가매립량
                    col_44 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[5]".format(i)).text
                    # 이동량
                    col_55 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[6]".format(i)).text

                    col_66 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[7]".format(i)).text

                    col_77 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[8]".format(i)).text

                    col_88 = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[1]/table/tbody/tr[{}]/td[9]".format(i)).text

                    col_1.append(col_11)
                    col_2.append(col_22)
                    col_3.append(col_33)
                    col_4.append(col_44)
                    col_5.append(col_55)
                    col_6.append(col_66)
                    col_7.append(col_77)
                    col_8.append(col_88)

                    print(Counts,".",col_11,col_22,col_33,col_44,col_55,col_66,col_77,col_88)
                    Counts +=1
                driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div[3]/div[2]/div/div/div[2]/div/div/a[{}]".format(j)).click()
                driver.implicitly_wait(20)
                time.sleep(3)
            print(k)
except:
    print("종료")
    
df = pd.DataFrame()
df['인증구분'] = col_1
df['건물구분'] = col_2
df['건물명'] = col_3
df['신청업체명'] = col_4
df['지역'] = col_5
df['인증등급'] = col_6
df['인증일자'] = col_7
df['인증기관'] = col_8
df.to_excel(r"C:/Users/KED_Internet/바탕화면/ESG/monthly_data/ESG_건축물에너지효율등급_{}_{}_{}.xlsx".
            format(time.localtime()[0],time.localtime()[1],time.localtime()[2]), index=None)
# Out:
# 1 . 본인증 주거용 서초 프라임 헤센 신한종합건설(주) 서울 1등급 2021-06-28 한국부동산원
# 2 . 예비인증 주거용 이외 KOEN재난안전교육원 한국남동발전(주) 인천 1++등급 2021-06-28 한국건물에너지기술원
# 3 . 예비인증 주거용 경산 중산 C4-1블럭 공동주택 신축공사 대한토지신탁(주) 경북 1+등급 2021-06-28 한국생산성본부인증원
# 4 . 예비인증 주거용 이외 사송1중학교 교사 신축공사 경상남도교육청 경남 1+++등급 2021-06-28 한국교육녹색환경연구원
# 5 . 예비인증 주거용 이외 고덕국제화계획지구 군사시설 이전사업(생활관, 체육관, 숙소, 사격장) 한국토지주택공사 경기 1++등급 2021-06-28 한국생산성본부인증원
# 6 . 예비인증 주거용 이외 의정부동 19-1 레지던스 신축공사 주식회사 제이프랜 경기 1++등급 2021-06-28 한국생산성본부인증원
# 7 . 예비인증 주거용 신길동 3608 역세권 청년주택(공동주택) (주)랜드코퍼레이션 서울 1등급 2021-06-28 한국생산성본부인증원
# 8 . 본인증 주거용 이외 전라남도 인재개발원 전남개발공사 전남 1+등급 2021-06-28 한국건물에너지기술원
# 9 . 예비인증 주거용 이외 경양초등학교 광주광역시교육청 광주 1++등급 2021-06-25 한국생산성본부인증원
# 10 . 본인증 주거용 이외 미림 A-클래스 15차 오현주 서울 1++등급 2021-06-25 한국생산성본부인증원
# 11 . 본인증 주거용 이외 미림 A-클래스 15차 오현주 서울 1++등급 2021-06-25 한국생산성본부인증원
# 12 . 본인증 주거용 이외 삼송 더샵 미디어시티 포스코건설 경기 1+등급 2021-06-25 한국생산성본부인증원
# 13 . 본인증 주거용 트리쉐이드 리젠시(행정중심복합도시 2-4생활권 P2주상복합)(공동주택) (주)부원건설 세종특별자치시 1등급 2021-06-24 한국생산성본부인증원
# ...
