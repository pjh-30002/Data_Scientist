# %%
# 기본 라이브러리
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')
sns.set()
# %matplotlib inline

# 전처리 라이브러리
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA

# 경고메세지 숨기기
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 중간에 잘리는 컬럼없이 100개까지 Print / 소수점은 5번째까지
pd.set_option('display.max_columns', 100)
pd.options.display.float_format = '{:.5f}'.format

# %%
# 모델적용 라이브러리
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score

from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
import keras
from keras.utils.np_utils import to_categorical
from sklearn.utils import class_weight

from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier

# %%
#폰트 설정
import matplotlib.font_manager as fm
font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\Windows\\Fonts\\HARLOWSI.TTF',
#  'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  'C:\\Windows\\Fonts\\LEELAWDB.TTF',
#  'C:\\Windows\\Fonts\\MAIAN.TTF',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\HPSimplified_BdIt.ttf',
#  'C:\\Windows\\Fonts\\FRADMCN.TTF',
#  'C:\\Windows\\Fonts\\NIAGENG.TTF',
#  'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  'C:\\Windows\\Fonts\\GOTHICB.TTF',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  'C:\\Windows\\Fonts\\BOD_I.TTF',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\H2GTRE.TTF',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
# ...

# %%
import platform 

# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정


# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Deep Learning Model

# %% [markdown]
# ### ANN Model
# - 검증과 테스트 셋
# - 마지막 Dense의 경우 units를 나중에 0,1의 판정이 아닐 경우 값을 바꿔야함.
#     - 종속변수의 컬럼이 0,1,2면 3으로 0,1,2,3,4,5,6이면 7
# - EarlyStopping은 같은결과가 계속 나타나면 시간만 오래걸리니까 같은결과가 n번이상 나타나면 모델을 중단.(현재=3)
#
# - activation과 metrics, loss는 데이터에 맞게 변경해야할 수 있음

# %%
def ANN(X_Train, X_Test, Y_Train, Y_Test):

    classifier = Sequential()
    # Add hidden layer
    classifier.add(Dense(units = 256, kernel_initializer = 'uniform', activation = 'relu', input_dim = X_Train.shape[1]))
    classifier.add(Dropout(rate = 0.1))
    
    # Add hidden layer
    classifier.add(Dense(units = 128, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dropout(rate = 0.1))
    
    # Add hidden layer
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

    # Compiling the ANN
    classifier.compile(optimizer = 'adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    early_stop = EarlyStopping(monitor='accuracy', patience=3, verbose=1)
    
    # Fitting ANN
    classifier.fit(X_Train, Y_Train, batch_size = 10, epochs = 2, verbose = True,
                   callbacks=[early_stop])

    score, acc = classifier.evaluate(X_Train,Y_Train,batch_size=10)

    print('Train score :', score)
    print('Train Accuracy :', acc)

    # Predicting the Test
    y_pred = classifier.predict(X_Test)
    y_pred = (y_pred > 0.5)

    print("*"*20)
    score, acc = classifier.evaluate(X_Test, Y_Test, batch_size=10)

    print('Test score:', score)
    print('Test accuracy:', acc)

    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(Y_Test, y_pred)
    
    import seaborn as sns
    p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    
    #import classification_report
    from sklearn.metrics import classification_report
    print("Classification Result\n",classification_report(Y_Test,y_pred))

# %% [markdown]
# ### LSTM
# - 검증과 테스트 셋
# - 마지막 Dense의 경우 units를 나중에 0,1의 판정이 아닐 경우 값을 바꿔야함.
#     - 종속변수의 컬럼이 0,1,2면 3으로 0,1,2,3,4,5,6이면 7
# - EarlyStopping은 같은결과가 계속 나타나면 시간만 오래걸리니까 같은결과가 n번이상 나타나면 모델을 중단.(현재=3)
#
# - activation과 metrics, loss는 데이터에 맞게 변경해야할 수 있음

# %%
def LSTM(X_Train,X_Test,Y_Train,Y_Test):
    from keras.layers import LSTM 
    from keras.models import Sequential 
    from keras.layers import Dense, Dropout
    import keras.backend as K 
    from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
    
    K.clear_session()
    
    X_Train_Ls = X_Train.values.reshape(X_Train.shape[0],X_Train.shape[1],1)
    X_Test_Ls = X_Test.values.reshape(X_Test.shape[0],X_Test.shape[1],1)
    
    model = Sequential() # Sequeatial Model 
    model.add(LSTM(100, input_shape=(x_train.shape[1], 1))) # (timestep, feature) 
    model.add(Dense(128)) # output = 1 
    model.add(Dropout(rate=0.1))
    model.add(Dense(64)) # output = 1 
    model.add(Dropout(rate=0.1))
    model.add(Dense(32)) # output = 1 
    model.add(Dropout(rate=0.1))
    model.add(Dense(1)) # output = 1 

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy']) 
    model.summary()
    
    early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)

    history = model.fit(X_Train_Ls, Y_Train, epochs=100, batch_size=5, verbose=1, validation_data=(X_Test_Ls, Y_Test), callbacks=[early_stop])
    
    h1 = plt.plot(history.history['accuracy'])
    h1 = plt.plot(history.history['val_accuracy'])
    h1 = plt.title("model accuracy")
    h1 = plt.ylabel('accuracy')
    h1 = plt.xlabel('epoch')
    h1 = plt.legend(['train','test'], loc='upper left')
    plt.show()
    
    h2 = plt.plot(history.history['loss'])
    h2 = plt.plot(history.history['val_loss'])
    h2 = plt.title("model loss")
    h2 = plt.ylabel('loss')
    h2 = plt.xlabel('epoch')
    h2 = plt.legend(['train','test'], loc='upper left')
    plt.show()
    
    score, acc = model.evaluate(X_Train_Ls,Y_Train,batch_size=10)

    print('Train score :', score)
    print('Train Accuracy :', acc)

    # Predicting the Test
    y_pred = model.predict(X_Test_Ls)
    y_pred = (y_pred > 0.5)

    print("*"*20)
    score, acc = model.evaluate(X_Test_Ls, Y_Test, batch_size=10)

    print('Test score:', score)
    print('Test accuracy:', acc)

    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(Y_Test, y_pred)
    
    import seaborn as sns
    p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    
    #import classification_report
    from sklearn.metrics import classification_report
    print("Classification Result\n",classification_report(Y_Test,y_pred))

# %% [markdown]
# ### CNN

# %%
def Change_shape(x_train,x_test,y_train,y_test):
    x_train = x_train.reshape(-1, x_train.shape[1],1)
    x_test = x_test.reshape(-1, x_test.shape[1],1)
    y_train = y_train.reshape(-1, y_train.shape[1],1)
    y_test = y_test.reshape(-1, y_test.shape[1],1)
    
    print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    
    return x_train,x_test,y_train,y_test

def CNN(x_train,x_test,y_train,y_test):
    
    patience = 5 # 사용자가 변경
    epochs= 50 # 사용자가 변경
    
    model = Sequential()
    
    model.add(Conv1D, kernel_size=2, input_shape=(x_train.shape[1],1)) # X의 차원에 따라 input_shape가 변화함
    model.add(MaxPooling1D(pool_size=2)) # Pooling layer는 convalution layer의 출력 데이터를 입력으로 받아서 출력 데이터의 크기를 줄이거나 특정 데이터를 강조하는 용도로 사용됨. max, average, min이 있고 정사각 행렬의 최대값,평균, 최소값으로 동작이 됨.
    model.add(Flatten()) # 데이터를 배열 형태로 만드는 layer
    model.add(Dropout(0.7)) # 과적합 방지
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.7)) # 과적합 방지
    
    model.add(Dense(32))
    model.add(Activation('relu'))
    model.add(Dropout(0.7))
              
    model.add(Dense(1)) # 종속변수 class 가 0,1일 경우 dense = 1
    model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
    
    print("만들어진 분석 모델\n",model.summary())
    
    early_stop = EarlyStaoping(monitor='accuracy', patience = patience, verbose=1)    
    history = model.fit(x_train, y_train, epochs=epochs, verbose=1, validation_split=0.2, callbacks=[early_stop])
    
    h1 = plt.plot(history.history['accuracy'])
    h1 = plt.plot(history.history['val_accuracy'])
    h1 = plt.title("model accuracy")
    h1 = plt.ylabel('accuracy')
    h1 = plt.xlabel('epoch')
    h1 = plt.legend(['train','validation'], loc='upper left')
    plt.show()
    
    h2 = plt.plot(history.history['loss'])
    h2 = plt.plot(history.history['val_loss'])
    h2 = plt.title("model loss")
    h2 = plt.ylabel('loss')
    h2 = plt.xlabel('epoch')
    h2 = plt.legend(['train','validation'], loc='upper left')
    plt.show()
    
    score, acc = model.evaluate(x_train,y_train)

    print('Train score :', score)
    print('Train Accuracy :', acc)

    # Predicting the Test
    y_pred = model.predict(x_test)
    y_pred = (y_pred > 0.5)

    print("*"*20)
    score, acc = model.evaluate(x_test, y_test)

    print('validation score:', score)
    print('validation accuracy:', acc)

    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)
    
    import seaborn as sns
    p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')
    
    #import classification_report
    from sklearn.metrics import classification_report
    print("Classification Result\n",classification_report(y_test,y_pred))
